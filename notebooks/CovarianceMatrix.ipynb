# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# Out:
# C:\Users\madsh\anaconda3\lib\site-packages\scipy\__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.24.1
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"

# %%
a = np.cov(df[[str(i) for i in range(1,26)]].to_numpy().T)

# %%
dfa = pd.DataFrame(a)
c = sns.diverging_palette(10, 220, as_cmap=True)
fig, ax = plt.subplots(figsize=(10,10))
sns.heatmap(dfa, ax=ax, square=True, cmap = c, annot=False,center=0)
ax.set_title("Covariance Matrix of the questions' answers")
# Out:
# Text(0.5, 1.0, "Covariance Matrix of the questions' answers")

# %%
fig.savefig("CovMatrix.svg")
